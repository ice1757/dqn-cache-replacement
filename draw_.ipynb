# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import make_interp_spline, BSpline



# y=[0.21767476, 1.2919996,  4.14791927, 0.78838882, 0.21281268 , 0.80031576]
# x=np.arange(0, len(y), 1)

# l_ =[0, 0, 0, 0, 0, 1, 0, 0, 2, 1, 2, 1, 1, 2, 1, 2, 2, 2, 2]
l_ = [2, 2, 2, 2, 3, 3, 2, 1, 3, 3, 3, 1, 1, 2, 2, 1, 3, 1, 1]
# spl = make_interp_spline(x, y)  # type: BSpline
# x_ = np.linspace(x.min(), x.max(), 500)
# y_ = spl(x_)
plt.plot(19,5)
# plt.plot(x_, y_)
# plt.figure(figsize=(20,5), facecolor=(1,1,1,1))
for i in range(len(l_)):
    if l_[i] == 3:
        plt.arrow(i,1,0,-0.2,width=0.1,head_width=0.3) ## blue
    elif l_[i] == 1:
        plt.arrow(i,1,0,-0.2,width=0.1,head_width=0.3, facecolor = "yellow")
    else:
        plt.arrow(i,1,0,-0.2,width=0.1,head_width=0.3, facecolor = "red")
ax = plt.gca()

ax.axes.xaxis.set_visible(False)
ax.axes.yaxis.set_visible(False)
# plt.arrow(0,1,0,-1,width=0.1,head_width=0.3)
# plt.arrow(1,1,0,-1, width=0.1,head_width=0.3, facecolor="red" )
# plt.savefig("./fig/zipf_t"+".png", facecolor= (1,1,1,1))
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

file_name = 'zipf_250_9000_cr3000.txt'
f = open("./dataset/req_trace/"+file_name, "r")
test_data = eval(f.read())
f.close()
save_path = "dyna-zipf1-1"
# print(test_data[:999])
# [:999] [1000:1999] [2000:2999]
test_data_seg = test_data[0:2999]
set_data = set(test_data_seg)
set_data_ct =[]
# print(set_data)

for i in range(1, 250):
    if i in set_data:
        set_data_ct.append(test_data_seg.count(i))
    else:
        set_data_ct.append(0)
# print(set_data_ct)
plt.figure(figsize=(10,5), facecolor=(1,1,1,1))
plt.plot(np.arange(len(set_data_ct)), set_data_ct, label="", alpha = 1, color='C0')
plt.ylabel("Request Count")
plt.xlabel("Content ID")
plt.title("Dyna-Zipf-1 Request Distribution")
plt.legend()
# plt.savefig("./fig/"+save_path+".png", facecolor= (1,1,1,1))
plt.savefig("./fig/"+save_path+".png", dpi=500, bbox_inches='tight', facecolor= (1,1,1,1))

# plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import matplotlib.pyplot as plt
import numpy as np

file_name = 'zipf_250_9000_cr3000.txt'
f = open("./dataset/req_trace/"+file_name, "r")
test_data = eval(f.read())
f.close()
save_path = "dyna-zip1-2"
# print(test_data[:999])
# [:999] [1000:1999] [2000:2999]
test_data_seg = test_data[3000:5999]
set_data = set(test_data_seg)
set_data_ct =[]
# print(set_data)

for i in range(1, 250):
    if i in set_data:
        set_data_ct.append(test_data_seg.count(i))
    else:
        set_data_ct.append(0)
# print(set_data_ct)

plt.figure(figsize=(10,5), facecolor=(1,1,1,1))
plt.plot(np.arange(len(set_data_ct)), set_data_ct, label="", alpha = 1, color='C0')
plt.ylabel("Request Count")
plt.xlabel("Content ID")
# plt.title("Dyna-Zipf-1 Request Distribution")
plt.legend()
# plt.savefig("./fig/"+save_path+".png", facecolor= (1,1,1,1))
plt.savefig("./fig/"+save_path+".png", dpi=500, bbox_inches='tight', facecolor= (1,1,1,1))

# plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import matplotlib.pyplot as plt
import numpy as np

file_name = 'zipf_250_9000_cr3000.txt'
f = open("./dataset/req_trace/"+file_name, "r")
test_data = eval(f.read())
f.close()
save_path = "dyna-zip1-3"
# print(test_data[:999])
# [:999] [1000:1999] [2000:2999]
test_data_seg = test_data[6000:8999]
set_data = set(test_data_seg)
set_data_ct =[]
# print(set_data)

for i in range(1, 250):
    if i in set_data:
        set_data_ct.append(test_data_seg.count(i))
    else:
        set_data_ct.append(0)
# print(set_data_ct)

plt.figure(figsize=(10,5), facecolor=(1,1,1,1))
plt.plot(np.arange(len(set_data_ct)), set_data_ct, label="", alpha = 1, color='C0')
plt.ylabel("Request Count")
plt.xlabel("Content ID")
# plt.title("Zipf Request Distribution")
plt.legend()
# plt.savefig("./fig/"+save_path+".png", facecolor= (1,1,1,1))
plt.savefig("./fig/"+save_path+".png", dpi=500, bbox_inches='tight', facecolor= (1,1,1,1))

# plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import matplotlib.pyplot as plt
import numpy as np

file_name = 'zipf_250_9000_cps.txt'
f = open("./dataset/req_trace/"+file_name, "r")
test_data = eval(f.read())
f.close()
save_path = "zip2-1"
# print(test_data[:999])
# [:999] [1000:1999] [2000:2999]
test_data_seg = test_data[0:2999]
set_data = set(test_data_seg)
set_data_ct =[]
# print(set_data)

for i in range(1, 250):
    if i in set_data:
        set_data_ct.append(test_data_seg.count(i))
    else:
        set_data_ct.append(0)
# print(set_data_ct)

plt.figure(figsize=(10,5), facecolor=(1,1,1,1))
plt.plot(np.arange(len(set_data_ct)), set_data_ct, label="", alpha = 1, color='C0')
plt.ylabel("Request Count")
plt.xlabel("Content ID")
plt.title("Dyna-Zipf-2 Request Distribution")
plt.legend()
# plt.savefig("./fig/"+save_path+".png", facecolor= (1,1,1,1))
# plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import matplotlib.pyplot as plt
import numpy as np

file_name = 'zipf_250_9000_cps.txt'
f = open("./dataset/req_trace/"+file_name, "r")
test_data = eval(f.read())
f.close()
save_path = "zip2-2"
# print(test_data[:999])
# [:999] [1000:1999] [2000:2999]
test_data_seg = test_data[3000:5999]
set_data = set(test_data_seg)
set_data_ct =[]
# print(set_data)

for i in range(1, 250):
    if i in set_data:
        set_data_ct.append(test_data_seg.count(i))
    else:
        set_data_ct.append(0)
# print(set_data_ct)

plt.figure(figsize=(10,5), facecolor=(1,1,1,1))
plt.plot(np.arange(len(set_data_ct)), set_data_ct, label="", alpha = 1, color='C0')
plt.ylabel("Request Count")
plt.xlabel("Content ID")
plt.title("Zipf Request Distribution")
plt.legend()
# plt.savefig("./fig/"+save_path+".png", facecolor= (1,1,1,1))
# plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import matplotlib.pyplot as plt
import numpy as np

file_name = 'zipf_250_9000_cps.txt'
f = open("./dataset/req_trace/"+file_name, "r")
test_data = eval(f.read())
f.close()
save_path = "zip2-3"
# print(test_data[:999])
test_data_seg = test_data[5999:8999]
set_data = set(test_data_seg)
set_data_ct =[]
# print(set_data)

for i in range(1, 250):
    if i in set_data:
        set_data_ct.append(test_data_seg.count(i))
    else:
        set_data_ct.append(0)

plt.figure(figsize=(10,5), facecolor=(1,1,1,1))
plt.plot(np.arange(len(set_data_ct)), set_data_ct, label="", alpha = 1, color='C0')
plt.ylabel("Request Count")
plt.xlabel("Content ID")
plt.title("Zipf Request Distribution")
plt.legend()
# plt.savefig("./fig/"+save_path+".png", facecolor= (1,1,1,1))
# plt.savefig("./fig/"+save_path+".png", dpi=100, bbox_inches='tight', facecolor= (1,1,1,1))

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

save_path = "cache_size_compare_same_size_1"

s = ["10", "20", "30"]


fifo = [43.67, 63.82, 79.71] 
lru =  [48.49, 67.76, 82.11] 
lfu =  [43.98, 54.26, 65.54] 
random = [48.18, 69.50, 83.12]
gds = [51.95, 75.18, 87.59] 
dqn =  [67.00, 82.50, 90.35] 
belady = [70.07, 86.20, 93.75]

plt.figure(figsize=(8,5), facecolor=(1,1,1,1))
plt.title('')
plt.plot(s, fifo, color='green', label='FIFO', marker= 'o')
plt.plot(s, lru, color='gray', label='LRU', marker= 'o')
plt.plot(s, lfu, color='tan', label='LFU', marker= 'o')
plt.plot(s, random, color='palegreen', label='Random', marker= 'o')
plt.plot(s, gds, color='navy', label='GDS', marker= 'o')
plt.plot(s, dqn, color='mediumpurple', label='OURS', marker= 'o')
plt.plot(s, belady, color='red', label='Belady', marker= 'o')


plt.legend()

plt.xlabel('Cache Size')
plt.ylabel('Raw hit ratio(%)')
# plt.savefig("./fig/"+save_path+".png", facecolor= (1,1,1,1))
# plt.savefig("./fig/"+save_path+".png", dpi=500, bbox_inches='tight', facecolor= (1,1,1,1))

plt.show()

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

save_path = "cache_size_compare_diff_content_size_1"

s = ["10", "20", "30"]


fifo = [39.68, 54.87, 68.65] 
lru =  [43.17, 58.11, 72.65] 
lfu =  [40.58, 52.03, 60.25] 
random = [45.34, 62.73, 77]
gds = [44.01, 62.10, 76.95] 
dqn =  [58.24, 74.36, 87.08] 
belady = [65.20, 79.64, 89.36]

plt.figure(figsize=(8,5), facecolor=(1,1,1,1))
plt.title('')
plt.plot(s, fifo, color='green', label='FIFO', marker= 'o')
plt.plot(s, lru, color='gray', label='LRU', marker= 'o')
plt.plot(s, lfu, color='tan', label='LFU', marker= 'o')
plt.plot(s, random, color='palegreen', label='Random', marker= 'o')
plt.plot(s, gds, color='navy', label='GDS', marker= 'o')
plt.plot(s, dqn, color='mediumpurple', label='OURS', marker= 'o')
plt.plot(s, belady, color='red', label='Belady', marker= 'o')


plt.legend()

plt.xlabel('Cache Size')
plt.ylabel('Raw hit ratio(%)')
# plt.savefig("./fig/"+save_path+".png", facecolor= (1,1,1,1))
# plt.savefig("./fig/"+save_path+".png", dpi=500, bbox_inches='tight', facecolor= (1,1,1,1))

plt.show()

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

save_path = "snm_content_size_compareoo"

s = ["1(80%)2(10%)3(10%)", "1(33%)2(33%)3(33%)", "1(10%)2(10%)3(80%)"]


fifo = [39.68, 31.15, 28.51] # [39.68, 31.15, 28.51] [54.22, 43.27, 38.62] [41.55, 30.63, 24.25]
lru = [43.17, 33.05, 28.36] # [43.17, 33.05, 28.36] [60.92, 45.66, 39.14] [46.30, 33.42, 24.36]
lfu =  [40.58, 34.78, 28.85] # [40.58, 34.78, 28.85] [51.83, 30.16, 27.74] [45.53, 31.45, 18.06]
random =  [40.58, 34.78, 28.85] #[45.34, 36.24, 31.09] [56.01, 43.51, 39.88] [44.44, 31.84, 24.35]
gds = [44.01, 33.54, 29.59] # [44.01, 33.54, 29.59] [54.34, 43.74, 37.78] [42.11, 29.47, 24.01]
dqn21 = [55.71, 46.09, 34.52]
dqn = [58.24, 47.17, 44.00] # [58.24, 47.17, 44.00] [67.01, 54.94, 50.21] [53.98, 40.52, 31.35]
belady = [65.20, 54.88, 48.56] # [65.20, 54.88, 48.56] [74.00, 63.97, 59.70] [65.68, 52.17, 44.56]
belady_s = [62.80, 36.88, 36.79]  # [62.80, 36.88, 36.79] [70.20, 37.57, 31.20] [65.00, 32.42, 20.37]

plt.figure(figsize=(8,5), facecolor=(1,1,1,1))
plt.title('SNM Content size Analysis')
plt.plot(s, fifo, color='green', label='FIFO', marker= 'o')
plt.plot(s, lru, color='gray', label='LRU', marker= 'o')
plt.plot(s, lfu, color='tan', label='LFU', marker= 'o')
plt.plot(s, random, color='palegreen', label='Random', marker= 'o')
plt.plot(s, gds, color='navy', label='GDS', marker= 'o')
plt.plot(s, dqn21, color='b', label='DQN[16]', marker= 'o')
plt.plot(s, dqn, color='mediumpurple', label='OURS', marker= 'o')
plt.plot(s, belady, color='red', label='Belady', marker= 'o')
plt.plot(s, belady_s, color='pink', label='Belady-size', marker= 'o')


plt.legend()

plt.xlabel('content size ')
plt.ylabel('Raw hit ratio(%)')
# plt.savefig("./fig/"+save_path+".png", facecolor= (1,1,1,1))
# plt.savefig("./fig/"+save_path+".png", dpi=500, bbox_inches='tight', facecolor= (1,1,1,1))


plt.show()

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

save_path = "zipf1_content_size_compareoo"

s = ["1(80%)2(10%)3(10%)", "1(33%)2(33%)3(33%)", "1(10%)2(10%)3(80%)"]


fifo = [54.93, 43.64, 35.67] # [39.68, 31.15, 28.51] [54.22, 43.27, 38.62] [41.55, 30.63, 24.25]
lru = [61.42, 48.72, 38.94] # [43.17, 33.05, 28.36] [60.92, 45.66, 39.14] [46.30, 33.42, 24.36]
lfu =  [50.40, 36.19, 31.72] # [40.58, 34.78, 28.85] [51.83, 30.16, 27.74] [45.53, 31.45, 18.06]
random =  [56.91, 44.90, 34.87] #[45.34, 36.24, 31.09] [56.01, 43.51, 39.88] [44.44, 31.84, 24.35]
gds = [55.99, 42.63, 35.96] # [44.01, 33.54, 29.59] [54.34, 43.74, 37.78] [42.11, 29.47, 24.01]
dqn21 =[65.74, 53.64, 43.82]
dqn = [67.01, 57.10, 49.88] # [58.24, 47.17, 44.00] [67.01, 54.94, 50.21] [53.98, 40.52, 31.35]
belady = [74.00, 64.78, 55.91] # [65.20, 54.88, 48.56] [74.00, 63.97, 59.70] [65.68, 52.17, 44.56]
belady_s = [70.20, 38.36, 22.88] # [62.80, 36.88, 36.79] [70.20, 37.57, 31.20] [65.00, 32.42, 20.37]

plt.figure(figsize=(8,5), facecolor=(1,1,1,1))
plt.title('Dyna-Zipf-1 Content size Analysis')
plt.plot(s, fifo, color='green', label='FIFO', marker= 'o')
plt.plot(s, lru, color='gray', label='LRU', marker= 'o')
plt.plot(s, lfu, color='tan', label='LFU', marker= 'o')
plt.plot(s, random, color='palegreen', label='Random', marker= 'o')
plt.plot(s, gds, color='navy', label='GDS', marker= 'o')
plt.plot(s, dqn21, color='b', label='DQN[16]', marker= 'o')
plt.plot(s, dqn, color='mediumpurple', label='OURS', marker= 'o')
plt.plot(s, belady, color='red', label='Belady', marker= 'o')
plt.plot(s, belady_s, color='pink', label='Belady-size', marker= 'o')


plt.legend()

plt.xlabel('content size ')
plt.ylabel('Raw hit ratio(%)')
# plt.savefig("./fig/"+save_path+".png", facecolor = (1,1,1,1))
plt.savefig("./fig/"+save_path+".png", dpi=500, bbox_inches='tight', facecolor= (1,1,1,1))

plt.show()

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

save_path = "zipf2_contentsize_compareoo"

s = ["1(80%)2(10%)3(10%)", "1(33%)2(33%)3(33%)", "1(10%)2(10%)3(80%)"]


fifo = [41.55, 30.63, 24.25] # [39.68, 31.15, 28.51] [54.22, 43.27, 38.62] [41.55, 30.63, 24.25]
lru = [46.30, 33.42, 24.36] # [43.17, 33.05, 28.36] [60.92, 45.66, 39.14] [46.30, 33.42, 24.36]
lfu = [45.53, 31.45, 18.06] # [40.58, 34.78, 28.85] [51.83, 30.16, 27.74] [45.53, 31.45, 18.06]
random =  [44.44, 31.84, 24.35] #[45.34, 36.24, 31.09] [56.01, 43.51, 39.88] [44.44, 31.84, 24.35]
gds = [42.11, 29.47, 24.01] # [44.01, 33.54, 29.59] [54.34, 43.74, 37.78] [42.11, 29.47, 24.01]
dqn21 = [52.63, 38.94, 30.64]
dqn = [53.98, 40.52, 31.35] # [58.24, 47.17, 44.00] [67.01, 54.94, 50.21] [53.98, 40.52, 31.35]
belady = [65.68, 52.17, 44.56] # [65.20, 54.88, 48.56] [74.00, 63.97, 59.70] [65.68, 52.17, 44.56]
belady_s = [65.00, 32.42, 20.37]  # [62.80, 36.88, 36.79] [70.20, 37.57, 31.20] [65.00, 32.42, 20.37]

plt.figure(figsize=(8,5), facecolor=(1,1,1,1))
plt.title('Dyna-Zipf-2 Content size Analysis')
plt.plot(s, fifo, color='green', label='FIFO', marker= 'o')
plt.plot(s, lru, color='gray', label='LRU', marker= 'o')
plt.plot(s, lfu, color='tan', label='LFU', marker= 'o')
plt.plot(s, random, color='palegreen', label='Random', marker= 'o')
plt.plot(s, gds, color='navy', label='GDS', marker= 'o')
plt.plot(s, dqn21, color='b', label='DQN[16]', marker= 'o')
plt.plot(s, dqn, color='mediumpurple', label='OURS', marker= 'o')
plt.plot(s, belady, color='red', label='Belady', marker= 'o')
plt.plot(s, belady_s, color='pink', label='Belady-size', marker= 'o')


plt.legend()

plt.xlabel('content size ')
plt.ylabel('Raw hit ratio(%)')
# plt.savefig("./fig/"+save_path+".png", facecolor= (1,1,1,1))
plt.savefig("./fig/"+save_path+".png", dpi=500, bbox_inches='tight', facecolor= (1,1,1,1))

plt.show()

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

save_path = "vskind_s"

s = ["50", "100", "150"]


fifo = [43.67, 28.82, 25.58] 
lru =  [48.49, 30.34, 26.91] 
lfu =  [43.98, 16.58, 7.12] 
random = [48.18, 31.46, 29.89]
gds = [51.95, 33.98, 32.77] 
dqn =  [67.00, 43.46, 38.61] 
belady = [70.07, 54.55, 52.71]

plt.figure(figsize=(8,5), facecolor=(1,1,1,1))
plt.title('')
plt.plot(s, fifo, color='green', label='FIFO', marker= 'o')
plt.plot(s, lru, color='gray', label='LRU', marker= 'o')
plt.plot(s, lfu, color='tan', label='LFU', marker= 'o')
plt.plot(s, random, color='palegreen', label='Random', marker= 'o')
plt.plot(s, gds, color='navy', label='GDS', marker= 'o')
plt.plot(s, dqn, color='mediumpurple', label='OURS', marker= 'o')
plt.plot(s, belady, color='red', label='Belady', marker= 'o')


plt.legend()

plt.xlabel('Number of Request\'s kind')
plt.ylabel('Raw hit ratio(%)')
# plt.savefig("./fig/"+save_path+".png", facecolor= (1,1,1,1))
plt.savefig("./fig/"+save_path+".png", dpi=500, bbox_inches='tight', facecolor= (1,1,1,1))


plt.show()

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

save_path = "vskind_di"

s = ["50", "100", "150"]


fifo = [39.68, 25.13, 21.38] 
lru =  [43.17, 25.17, 21.69] 
lfu =  [40.58, 19.7, 10.03] 
random = [45.34, 28.5, 26.46]
gds = [44.01, 29.05, 28.05] 
dqn =  [58.24, 35.33, 34.49] 
belady = [65.20, 46.38, 44.41]
belady_size = [62.80, 46.24, 45.12]

plt.figure(figsize=(8,5), facecolor=(1,1,1,1))
plt.title('')
plt.plot(s, fifo, color='green', label='FIFO', marker= 'o')
plt.plot(s, lru, color='gray', label='LRU', marker= 'o')
plt.plot(s, lfu, color='tan', label='LFU', marker= 'o')
plt.plot(s, random, color='palegreen', label='Random', marker= 'o')
plt.plot(s, gds, color='navy', label='GDS', marker= 'o')
plt.plot(s, dqn, color='mediumpurple', label='OURS', marker= 'o')
plt.plot(s, belady, color='red', label='Belady', marker= 'o')
plt.plot(s, belady_size, color='dodgerblue', label='Belady-size', marker= 'o')

plt.legend()

plt.xlabel('Number of Request\'s kind')
plt.ylabel('Raw hit ratio(%)')
# plt.savefig("./fig/"+save_path+".png", facecolor= (1,1,1,1))
plt.savefig("./fig/"+save_path+".png", dpi=500, bbox_inches='tight', facecolor= (1,1,1,1))


plt.show()

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

save_path = "q9compare"

s = ["cache size : 20/request kind : 50", "cache size : 70/request kind : 140"]


fifo = [63.82, 67.66] 
lru =  [67.76, 71.96] 
lfu =  [54.26, 59.77] 
random = [69.50, 74.45]
gds = [75.18, 80.25] 
dqn =  [82.50, 81.79] 
belady = [86.20, 89.80]
# 67.66, 71.96, 59.77, 74.45, 80.25, 81.79, 89.80
plt.figure(figsize=(8,5), facecolor=(1,1,1,1))
plt.title('')
plt.plot(s, fifo, color='green', label='FIFO', marker= 'o')
plt.plot(s, lru, color='gray', label='LRU', marker= 'o')
plt.plot(s, lfu, color='tan', label='LFU', marker= 'o')
plt.plot(s, random, color='palegreen', label='Random', marker= 'o')
plt.plot(s, gds, color='navy', label='GDS', marker= 'o')
plt.plot(s, dqn, color='mediumpurple', label='OURS', marker= 'o')
plt.plot(s, belady, color='red', label='Belady', marker= 'o')


plt.legend()

# plt.xlabel('Cache Size')
plt.ylabel('Raw hit ratio(%)')
# plt.savefig("./fig/"+save_path+".png", facecolor= (1,1,1,1))
# plt.savefig("./fig/"+save_path+".png", dpi=500, bbox_inches='tight', facecolor= (1,1,1,1))

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from func_loader import load_csv_history, load_history
from func_draw import smooth_curve, draw_multi

eh_o = load_csv_history('./logs/reward.csv')
plt.plot(np.arange(len(eh_o)), eh_o, alpha=0.3, linestyle='-', color='C0', linewidth=1)
plt.plot(np.arange(len(eh_o)), smooth_curve(eh_o), alpha=1, linestyle='-', color='C0', linewidth=1)
# plt.plot(np.arange(len(eh_o)), smooth_curve(eh_o), label='our', alpha=1, linestyle='-', color='C0', linewidth=1)


# plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=3, fancybox=True, shadow=True)
plt.title('Reward')
plt.xlabel('episode')
plt.ylabel('reward')
# plt.savefig('./fig/reward.png', dpi=500, bbox_inches='tight', facecolor= (1,1,1,1))
plt.show()
